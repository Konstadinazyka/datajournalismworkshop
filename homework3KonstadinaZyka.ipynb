# %%
import pandas as pd
import matplotlib.pyplot as plt
import xlrd
import openpyxl as opyx

# %%
pd.__version__
# Out:
# '2.1.2'

# %%
#run this cell and we will speak about this in class
pd.set_option('display.float_format', lambda x: '%.1f' % x)

# %%
df1 = pd.read_excel('API_NY.GDP.MKTP.CD_DS2_en_excel_v2_4023900.xls',"2020")
df1
# Out:
#                     Country Name Country Code            GDP  population
# 0                          Aruba          ABW            NaN    106766.0
# 1    Africa Eastern and Southern          AFE 920792331527.7 677243299.0
# 2                    Afghanistan          AFG  20116137325.8  38928341.0
# 3     Africa Western and Central          AFW 784587603322.9 458803476.0
# 4                         Angola          AGO  58375976293.0  32866268.0
# ..                           ...          ...            ...         ...
# 261                       Kosovo          XKX   7716925356.1   1790133.0
# 262                  Yemen, Rep.          YEM            NaN  29825968.0
# 263                 South Africa          ZAF 335442101366.4  59308690.0
# 264                       Zambia          ZMB  18110631358.3  18383956.0
# 265                     Zimbabwe          ZWE  18051170798.9  14862927.0
#
# [266 rows x 4 columns]

# %%
df2 = pd.read_excel('resourcetradeearth_russia_all_wheat.xlsx',"Importers_2020")
df2
# Out:
#      Importer M.49 Importer ISO3       Importer  \
# 0                4           AFG    Afghanistan
# 1                8           ALB        Albania
# 2               24           AGO         Angola
# 3               31           AZE     Azerbaijan
# 4               36           AUS      Australia
# ..             ...           ...            ...
# 110            834           TZA       Tanzania
# 111            842           USA  United States
# 112            854           BFA   Burkina Faso
# 113            860           UZB     Uzbekistan
# 114            887           YEM          Yemen
#
#                       Importer region Resource  Year  Value (1000USD)  \
# 0           Central and Southern Asia    Wheat  2020           3243.3
# 1                              Europe    Wheat  2020          35917.1
# 2                  Sub-Saharan Africa    Wheat  2020          46093.8
# 3    Northern Africa and Western Asia    Wheat  2020         290906.7
# ...

# %%
df3 = pd.read_excel('resourcetradeearth_ukraine_all_wheat.xlsx', "Importers_2020")
df3
# Out:
#      Importer M.49 Importer ISO3            Importer  \
# 0              818           EGY               Egypt
# 1              360           IDN           Indonesia
# 2               50           BGD          Bangladesh
# 3              792           TUR              Turkey
# 4              586           PAK            Pakistan
# ..             ...           ...                 ...
# 116            136           CYM      Cayman Islands
# 117             70           BIH  Bosnia Herzegovina
# 118            340           HND            Honduras
# 119            428           LVA              Latvia
# 120            899           NaN          Areas, nes
#
#                                   Importer region Resource  Year  \
# 0                Northern Africa and Western Asia    Wheat  2020
# 1    Eastern and South-Eastern Asia (excl. China)    Wheat  2020
# 2                       Central and Southern Asia    Wheat  2020
# ...

# %%
df1 = df1.rename(columns={df1.columns[0]:'country_name',
                          df1.columns[1]:'country_code'})
df1
# Out:
#                     country_name country_code            GDP  population
# 0                          Aruba          ABW            NaN    106766.0
# 1    Africa Eastern and Southern          AFE 920792331527.7 677243299.0
# 2                    Afghanistan          AFG  20116137325.8  38928341.0
# 3     Africa Western and Central          AFW 784587603322.9 458803476.0
# 4                         Angola          AGO  58375976293.0  32866268.0
# ..                           ...          ...            ...         ...
# 261                       Kosovo          XKX   7716925356.1   1790133.0
# 262                  Yemen, Rep.          YEM            NaN  29825968.0
# 263                 South Africa          ZAF 335442101366.4  59308690.0
# 264                       Zambia          ZMB  18110631358.3  18383956.0
# 265                     Zimbabwe          ZWE  18051170798.9  14862927.0
#
# [266 rows x 4 columns]

# %%
df2 = df2.rename(columns={df2.columns[0]:'importerm49',
                          df2.columns[1]:'country_code',
                          df2.columns[2]:'importer',
                          df2.columns[3]:'importer_region',
                          df2.columns[6]:'value_in_usd_russia',
                          df2.columns[7]:'weight_1000kg_russia'})
df2
# Out:
#      importerm49 country_code       importer  \
# 0              4          AFG    Afghanistan
# 1              8          ALB        Albania
# 2             24          AGO         Angola
# 3             31          AZE     Azerbaijan
# 4             36          AUS      Australia
# ..           ...          ...            ...
# 110          834          TZA       Tanzania
# 111          842          USA  United States
# 112          854          BFA   Burkina Faso
# 113          860          UZB     Uzbekistan
# 114          887          YEM          Yemen
#
#                       importer_region Resource  Year  value_in_usd_russia  \
# 0           Central and Southern Asia    Wheat  2020               3243.3
# 1                              Europe    Wheat  2020              35917.1
# 2                  Sub-Saharan Africa    Wheat  2020              46093.8
# 3    Northern Africa and Western Asia    Wheat  2020             290906.7
# ...

# %%
df3 = df3.rename(columns={df3.columns[0]:'importerm49',
                          df3.columns[1]:'country_code',
                          df3.columns[2]:'importer',
                          df3.columns[3]:'importer_region',
                          df3.columns[6]:'value_in_usd_ukraine',
                          df3.columns[7]:'weight_1000kg_ukraine'})
df3
# Out:
#      importerm49 country_code            importer  \
# 0            818          EGY               Egypt
# 1            360          IDN           Indonesia
# 2             50          BGD          Bangladesh
# 3            792          TUR              Turkey
# 4            586          PAK            Pakistan
# ..           ...          ...                 ...
# 116          136          CYM      Cayman Islands
# 117           70          BIH  Bosnia Herzegovina
# 118          340          HND            Honduras
# 119          428          LVA              Latvia
# 120          899          NaN          Areas, nes
#
#                                   importer_region Resource  Year  \
# 0                Northern Africa and Western Asia    Wheat  2020
# 1    Eastern and South-Eastern Asia (excl. China)    Wheat  2020
# 2                       Central and Southern Asia    Wheat  2020
# 3                Northern Africa and Western Asia    Wheat  2020
# ...

# %%
df4 = df1[['country_code','GDP','population']]
df4
# Out:
#     country_code            GDP  population
# 0            ABW            NaN    106766.0
# 1            AFE 920792331527.7 677243299.0
# 2            AFG  20116137325.8  38928341.0
# 3            AFW 784587603322.9 458803476.0
# 4            AGO  58375976293.0  32866268.0
# ..           ...            ...         ...
# 261          XKX   7716925356.1   1790133.0
# 262          YEM            NaN  29825968.0
# 263          ZAF 335442101366.4  59308690.0
# 264          ZMB  18110631358.3  18383956.0
# 265          ZWE  18051170798.9  14862927.0
#
# [266 rows x 3 columns]

# %%
df5 = df2[['country_code', 'importer','importer_region','value_in_usd_russia','weight_1000kg_russia']]
df5
# Out:
#     country_code       importer                   importer_region  \
# 0            AFG    Afghanistan         Central and Southern Asia
# 1            ALB        Albania                            Europe
# 2            AGO         Angola                Sub-Saharan Africa
# 3            AZE     Azerbaijan  Northern Africa and Western Asia
# 4            AUS      Australia         Australia and New Zealand
# ..           ...            ...                               ...
# 110          TZA       Tanzania                Sub-Saharan Africa
# 111          USA  United States                  Northern America
# 112          BFA   Burkina Faso                Sub-Saharan Africa
# 113          UZB     Uzbekistan         Central and Southern Asia
# 114          YEM          Yemen  Northern Africa and Western Asia
#
#      value_in_usd_russia  weight_1000kg_russia
# 0                 3243.3               11949.1
# 1                35917.1              152057.9
# ...

# %%
df6 = df3[['country_code', 'importer','importer_region','value_in_usd_ukraine','weight_1000kg_ukraine']]
df6
# Out:
#     country_code            importer  \
# 0            EGY               Egypt
# 1            IDN           Indonesia
# 2            BGD          Bangladesh
# 3            TUR              Turkey
# 4            PAK            Pakistan
# ..           ...                 ...
# 116          CYM      Cayman Islands
# 117          BIH  Bosnia Herzegovina
# 118          HND            Honduras
# 119          LVA              Latvia
# 120          NaN          Areas, nes
#
#                                   importer_region  value_in_usd_ukraine  \
# 0                Northern Africa and Western Asia             1302691.6
# 1    Eastern and South-Eastern Asia (excl. China)              656298.7
# 2                       Central and Southern Asia              294847.1
# 3                Northern Africa and Western Asia              310293.5
# 4                       Central and Southern Asia              322861.5
# ..                                            ...                   ...
# ...

# %%
df7 = pd.merge(df4, df5, on='country_code', how='left')
df7
# Out:
#     country_code            GDP  population      importer  \
# 0            ABW            NaN    106766.0           NaN
# 1            AFE 920792331527.7 677243299.0           NaN
# 2            AFG  20116137325.8  38928341.0   Afghanistan
# 3            AFW 784587603322.9 458803476.0           NaN
# 4            AGO  58375976293.0  32866268.0        Angola
# ..           ...            ...         ...           ...
# 261          XKX   7716925356.1   1790133.0           NaN
# 262          YEM            NaN  29825968.0         Yemen
# 263          ZAF 335442101366.4  59308690.0  South Africa
# 264          ZMB  18110631358.3  18383956.0           NaN
# 265          ZWE  18051170798.9  14862927.0      Zimbabwe
#
#                       importer_region  value_in_usd_russia  \
# 0                                 NaN                  NaN
# 1                                 NaN                  NaN
# 2           Central and Southern Asia               3243.3
# ...

# %%
df8 = pd.merge(df7, df6, on=['country_code','importer','importer_region'], how='left')
df8
# Out:
#     country_code            GDP  population      importer  \
# 0            ABW            NaN    106766.0           NaN
# 1            AFE 920792331527.7 677243299.0           NaN
# 2            AFG  20116137325.8  38928341.0   Afghanistan
# 3            AFW 784587603322.9 458803476.0           NaN
# 4            AGO  58375976293.0  32866268.0        Angola
# ..           ...            ...         ...           ...
# 261          XKX   7716925356.1   1790133.0           NaN
# 262          YEM            NaN  29825968.0         Yemen
# 263          ZAF 335442101366.4  59308690.0  South Africa
# 264          ZMB  18110631358.3  18383956.0           NaN
# 265          ZWE  18051170798.9  14862927.0      Zimbabwe
#
#                       importer_region  value_in_usd_russia  \
# 0                                 NaN                  NaN
# 1                                 NaN                  NaN
# 2           Central and Southern Asia               3243.3
# ...

# %%
df8[df8.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [country_code, GDP, population, importer, importer_region, value_in_usd_russia, weight_1000kg_russia, value_in_usd_ukraine, weight_1000kg_ukraine]
# Index: []

# %%
df8=df8.dropna()
df8
# Out:
#     country_code              GDP  population              importer  \
# 4            AGO    58375976293.0  32866268.0                Angola
# 5            ALB    14887629268.3   2837849.0               Albania
# 8            ARE   358868765174.9   9890400.0  United Arab Emirates
# 10           ARM    12641209802.1   2963234.0               Armenia
# 13           AUS  1327836171068.5  25693267.0             Australia
# ..           ...              ...         ...                   ...
# 247          UGA    37600368180.9  45741000.0                Uganda
# 251          USA 20953030000000.0 331501080.0         United States
# 257          VNM   271158442448.5  97338583.0               Vietnam
# 263          ZAF   335442101366.4  59308690.0          South Africa
# 265          ZWE    18051170798.9  14862927.0              Zimbabwe
#
#                                   importer_region  value_in_usd_russia  \
# 4                              Sub-Saharan Africa              46093.8
# ...

# %%
df9 = df8[(df8.importer_region.str.contains('Asia',case=False))&(df8.importer_region.str.contains('China',case=False))]
df9
# Out:
#     country_code             GDP  population         importer  \
# 106          IDN 1058423838345.1 273523621.0        Indonesia
# 119          JPN 5057758958706.6 125836021.0            Japan
# 123          KHM   25808561551.0  16718971.0         Cambodia
# 126          KOR 1637895802792.9  51836239.0  Korea, Republic
# 160          MMR   79852046611.0  54409794.0          Myanmar
# 169          MYS  337006066373.3  32365998.0         Malaysia
# 187          PHL  361489325230.7 109581085.0      Philippines
# 208          SGP  339998477930.0   5685807.0        Singapore
# 233          THA  501643653514.9  69799978.0         Thailand
# 257          VNM  271158442448.5  97338583.0          Vietnam
#
#                                   importer_region  value_in_usd_russia  \
# 106  Eastern and South-Eastern Asia (excl. China)              10813.5
# 119  Eastern and South-Eastern Asia (excl. China)                  4.9
# ...

# %%
row_count = len(df9)
print(row_count)
# Out:
# 10

# %%
wheat_importedeu = df8.loc[df8['importer_region'] == 'Europe']
wheat_importedeu
wheat_importedeu['weight_1000kg_russia'].sum() + wheat_importedeu['weight_1000kg_ukraine'].sum()
# Out:
# 1975485.5497263162
